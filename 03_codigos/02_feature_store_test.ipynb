# %% [markdown]
# # Introdução

# %% [markdown]
# Para rodar esse teste, primeiro a Feature Store deve ser configurada. Para isso, o comando feast apply deve ser executado no diretório criado para a Feature Store, que contém o arquivo .py com as configurações de FeatureViews e FeatureServices, além do arquivo .yaml que configura a Feature Store.
#
# Passos executados para configurar a Feature Store:
#
# 1. Para instalar o feast: pip install feast
# 2. Criação da pasta da Feature Store ("adult_income_project") com os arquivos .yaml e .py
# 3. feast apply no diretório da Feature Store
# 4. Para passar dados para online store: feast materialize 2024-01-01T00:00:00 2024-12-31T00:00:00

# %% [markdown]
# # Configuração Inicial

# %%
# Importando bibliotecas
import os
from datetime import datetime
import pandas as pd
from feast import FeatureStore


# Definindo paths
path_codigos = os.getcwd()
path_projeto = os.path.dirname(path_codigos)
path_data = os.path.join(path_projeto, "02_data")
path_bronze = os.path.join(path_data, "01_bronze")
path_silver = os.path.join(path_data, "02_silver")
feature_repo_path = os.path.join(path_projeto, "adult_income_project")

# Instanciando a Feature Store
store = FeatureStore(repo_path = feature_repo_path)
# Out:
# /Users/pedrosilva/Documents/01_Projetos/03_Feast_Test/venv_feast/lib/python3.12/site-packages/feast/repo_config.py:229: RuntimeWarning: `entity_key_serialization_version` is either not specified in the feature_store.yaml, or is specified to a value <= 1.This serialization version may cause errors when trying to write fields with the `Long` data type into the online store. Specifying `entity_key_serialization_version` to 2 is recommended for new projects.
#   warnings.warn(

# %% [markdown]
# # Explorando a Feature Store

# %% [markdown]
# ## Entities

# %%
for cur_entity in store.list_entities():
    print(cur_entity)
# Out:
# {
#   "spec": {
#     "name": "adult",
#     "joinKey": "adult_id"
#   },
#   "meta": {
#     "createdTimestamp": "2024-10-03T10:18:30.851776Z",
#     "lastUpdatedTimestamp": "2024-10-03T10:18:30.851776Z"
#   }
# }

# %% [markdown]
# ## Feature Views

# %%
# Listando Feature Views
for cur_fv in store.list_batch_feature_views():
    print(cur_fv)
# Out:
# {
#   "spec": {
#     "name": "adult_hist_social_data",
#     "entities": [
#       "adult"
#     ],
#     "features": [
#       {
#         "name": "age",
#         "valueType": "INT64"
#       },
#       {
#         "name": "race",
#         "valueType": "STRING"
#       },
#       {
#         "name": "education",
#         "valueType": "STRING"
#       },
#       {
#         "name": "education-num",
#         "valueType": "INT64"
#       },
#       {
#         "name": "marital-status",
#         "valueType": "STRING"
#       },
#       {
#         "name": "sex",
#         "valueType": "STRING"
#       },
#       {
#         "name": "native-country",
#         "valueType": "STRING"
#       }
#     ],
#     "ttl": "0s",
#     "batchSource": {
#       "type": "BATCH_FILE",
#       "timestampField": "event_timestamp",
#       "fileOptions": {
#         "uri": "/Users/pedrosilva/Documents/01_Projetos/03_Feast_Test/02_data/02_silver/adult_dataset_hist.parquet"
#       },
#       "dataSourceClassType": "feast.infra.offline_stores.file_source.FileSource",
#       "name": "adult_hist_db_source"
#     },
#     "online": true,
#     "entityColumns": [
#       {
#         "name": "adult_id",
#         "valueType": "INT64"
#       }
#     ]
#   },
#   "meta": {
#     "createdTimestamp": "2024-10-03T10:18:30.851827Z",
#     "lastUpdatedTimestamp": "2024-10-03T10:18:30.851827Z"
#   }
# }
# {
#   "spec": {
#     "name": "adult_hist_income_data",
#     "entities": [
#       "adult"
#     ],
#     "features": [
#       {
#         "name": "workclass",
#         "valueType": "STRING"
#       },
#       {
#         "name": "occupation",
#         "valueType": "STRING"
#       },
#       {
#         "name": "capital-gain",
#         "valueType": "INT64"
#       },
#       {
#         "name": "capital-loss",
#         "valueType": "INT64"
#       },
#       {
#         "name": "income",
#         "valueType": "STRING"
#       }
#     ],
#     "ttl": "0s",
#     "batchSource": {
#       "type": "BATCH_FILE",
#       "timestampField": "event_timestamp",
#       "fileOptions": {
#         "uri": "/Users/pedrosilva/Documents/01_Projetos/03_Feast_Test/02_data/02_silver/adult_dataset_hist.parquet"
#       },
#       "dataSourceClassType": "feast.infra.offline_stores.file_source.FileSource",
#       "name": "adult_hist_db_source"
#     },
#     "online": true,
#     "entityColumns": [
#       {
#         "name": "adult_id",
#         "valueType": "INT64"
#       }
#     ]
#   },
#   "meta": {
#     "createdTimestamp": "2024-10-03T10:18:30.851906Z",
#     "lastUpdatedTimestamp": "2024-10-03T10:18:30.851906Z"
#   }
# }
# {
#   "spec": {
#     "name": "adult_inf_income_data",
#     "entities": [
#       "adult"
#     ],
#     "features": [
#       {
#         "name": "workclass",
#         "valueType": "STRING"
#       },
#       {
#         "name": "occupation",
#         "valueType": "STRING"
#       },
#       {
#         "name": "capital-gain",
#         "valueType": "INT64"
#       },
#       {
#         "name": "capital-loss",
#         "valueType": "INT64"
#       }
#     ],
#     "ttl": "0s",
#     "batchSource": {
#       "type": "BATCH_FILE",
#       "timestampField": "event_timestamp",
#       "fileOptions": {
#         "uri": "/Users/pedrosilva/Documents/01_Projetos/03_Feast_Test/02_data/02_silver/adult_dataset_inf.parquet"
#       },
#       "dataSourceClassType": "feast.infra.offline_stores.file_source.FileSource",
#       "name": "adult_inf_db_source"
#     },
#     "online": true,
#     "entityColumns": [
#       {
#         "name": "adult_id",
#         "valueType": "INT64"
#       }
#     ]
#   },
#   "meta": {
#     "createdTimestamp": "2024-10-03T10:18:30.851964Z",
#     "lastUpdatedTimestamp": "2024-10-03T10:18:30.851964Z"
#   }
# }
# {
#   "spec": {
#     "name": "adult_inf_social_data",
#     "entities": [
#       "adult"
#     ],
#     "features": [
#       {
#         "name": "age",
#         "valueType": "INT64"
#       },
#       {
#         "name": "race",
#         "valueType": "STRING"
#       },
#       {
#         "name": "education",
#         "valueType": "STRING"
#       },
#       {
#         "name": "education-num",
#         "valueType": "INT64"
#       },
#       {
#         "name": "marital-status",
#         "valueType": "STRING"
#       },
#       {
#         "name": "sex",
#         "valueType": "STRING"
#       },
#       {
#         "name": "native-country",
#         "valueType": "STRING"
#       }
#     ],
#     "ttl": "0s",
#     "batchSource": {
#       "type": "BATCH_FILE",
#       "timestampField": "event_timestamp",
#       "fileOptions": {
#         "uri": "/Users/pedrosilva/Documents/01_Projetos/03_Feast_Test/02_data/02_silver/adult_dataset_inf.parquet"
#       },
#       "dataSourceClassType": "feast.infra.offline_stores.file_source.FileSource",
#       "name": "adult_inf_db_source"
#     },
#     "online": true,
#     "entityColumns": [
#       {
#         "name": "adult_id",
#         "valueType": "INT64"
#       }
#     ]
#   },
#   "meta": {
#     "createdTimestamp": "2024-10-03T10:18:30.852013Z",
#     "lastUpdatedTimestamp": "2024-10-03T10:18:30.852013Z"
#   }
# }

# %% [markdown]
# ## Feature Services

# %%
for cur_fs in store.list_feature_services():
    print(cur_fs)
# Out:
# {
#   "spec": {
#     "name": "adult_income_inf_v2",
#     "features": [
#       {
#         "featureViewName": "adult_inf_social_data",
#         "featureColumns": [
#           {
#             "name": "age",
#             "valueType": "INT64"
#           },
#           {
#             "name": "race",
#             "valueType": "STRING"
#           },
#           {
#             "name": "education",
#             "valueType": "STRING"
#           },
#           {
#             "name": "education-num",
#             "valueType": "INT64"
#           },
#           {
#             "name": "marital-status",
#             "valueType": "STRING"
#           },
#           {
#             "name": "sex",
#             "valueType": "STRING"
#           },
#           {
#             "name": "native-country",
#             "valueType": "STRING"
#           }
#         ]
#       },
#       {
#         "featureViewName": "adult_inf_income_data",
#         "featureColumns": [
#           {
#             "name": "workclass",
#             "valueType": "STRING"
#           },
#           {
#             "name": "occupation",
#             "valueType": "STRING"
#           },
#           {
#             "name": "capital-gain",
#             "valueType": "INT64"
#           },
#           {
#             "name": "capital-loss",
#             "valueType": "INT64"
#           }
#         ]
#       }
#     ]
#   },
#   "meta": {
#     "createdTimestamp": "2024-10-03T10:18:30.852074Z",
#     "lastUpdatedTimestamp": "2024-10-03T10:18:30.852074Z"
#   }
# }
# {
#   "spec": {
#     "name": "adult_income_inf_v1",
#     "features": [
#       {
#         "featureViewName": "adult_inf_social_data",
#         "featureColumns": [
#           {
#             "name": "race",
#             "valueType": "STRING"
#           },
#           {
#             "name": "education",
#             "valueType": "STRING"
#           }
#         ]
#       },
#       {
#         "featureViewName": "adult_inf_income_data",
#         "featureColumns": [
#           {
#             "name": "workclass",
#             "valueType": "STRING"
#           },
#           {
#             "name": "occupation",
#             "valueType": "STRING"
#           },
#           {
#             "name": "capital-gain",
#             "valueType": "INT64"
#           },
#           {
#             "name": "capital-loss",
#             "valueType": "INT64"
#           }
#         ]
#       }
#     ]
#   },
#   "meta": {
#     "createdTimestamp": "2024-10-03T10:18:30.852145Z",
#     "lastUpdatedTimestamp": "2024-10-03T10:18:30.852145Z"
#   }
# }
# {
#   "spec": {
#     "name": "adult_income_train_v2",
#     "features": [
#       {
#         "featureViewName": "adult_hist_social_data",
#         "featureColumns": [
#           {
#             "name": "age",
#             "valueType": "INT64"
#           },
#           {
#             "name": "race",
#             "valueType": "STRING"
#           },
#           {
#             "name": "education",
#             "valueType": "STRING"
#           },
#           {
#             "name": "education-num",
#             "valueType": "INT64"
#           },
#           {
#             "name": "marital-status",
#             "valueType": "STRING"
#           },
#           {
#             "name": "sex",
#             "valueType": "STRING"
#           },
#           {
#             "name": "native-country",
#             "valueType": "STRING"
#           }
#         ]
#       },
#       {
#         "featureViewName": "adult_hist_income_data",
#         "featureColumns": [
#           {
#             "name": "workclass",
#             "valueType": "STRING"
#           },
#           {
#             "name": "occupation",
#             "valueType": "STRING"
#           },
#           {
#             "name": "capital-gain",
#             "valueType": "INT64"
#           },
#           {
#             "name": "capital-loss",
#             "valueType": "INT64"
#           },
#           {
#             "name": "income",
#             "valueType": "STRING"
#           }
#         ]
#       }
#     ]
#   },
#   "meta": {
#     "createdTimestamp": "2024-10-03T10:18:30.852191Z",
#     "lastUpdatedTimestamp": "2024-10-03T10:18:30.852191Z"
#   }
# }
# {
#   "spec": {
#     "name": "adult_income_train_v1",
#     "features": [
#       {
#         "featureViewName": "adult_hist_social_data",
#         "featureColumns": [
#           {
#             "name": "race",
#             "valueType": "STRING"
#           },
#           {
#             "name": "education",
#             "valueType": "STRING"
#           }
#         ]
#       },
#       {
#         "featureViewName": "adult_hist_income_data",
#         "featureColumns": [
#           {
#             "name": "workclass",
#             "valueType": "STRING"
#           },
#           {
#             "name": "occupation",
#             "valueType": "STRING"
#           },
#           {
#             "name": "capital-gain",
#             "valueType": "INT64"
#           },
#           {
#             "name": "capital-loss",
#             "valueType": "INT64"
#           },
#           {
#             "name": "income",
#             "valueType": "STRING"
#           }
#         ]
#       }
#     ]
#   },
#   "meta": {
#     "createdTimestamp": "2024-10-03T10:18:30.852261Z",
#     "lastUpdatedTimestamp": "2024-10-03T10:18:30.852261Z"
#   }
# }

# %% [markdown]
# # Feature Retrieval (Offline Store)

# %% [markdown]
# ## Instanciando feature services

# %%
# Feature Services - v1
adult_income_fs_train_v1 = store.get_feature_service("adult_income_train_v1")
adult_income_fs_inf_v1 = store.get_feature_service("adult_income_inf_v1")

# Feature Services - v2
adult_income_fs_train_v2 = store.get_feature_service("adult_income_train_v2")
adult_income_fs_inf_v2 = store.get_feature_service("adult_income_inf_v2")

# %% [markdown]
# ## Capturando historical features para treino

# %%
# Entidades de interesse
entity_df = pd.DataFrame({"adult_id": [0, 1, 2], "event_timestamp": [datetime(2022,10,1), datetime(2022,10,1), datetime(2022,10,1)]})
entity_df
# Out:
#    adult_id event_timestamp
# 0         0      2022-10-01
# 1         1      2022-10-01
# 2         2      2022-10-01

# %%
# Train v1
training_df = store.get_historical_features(entity_df = entity_df, features = adult_income_fs_train_v1)
training_df.to_df()
# Out:
# WARNING:root:_list_feature_views will make breaking changes. Please use _list_batch_feature_views instead. _list_feature_views will behave like _list_all_feature_views in the future.
#    adult_id           event_timestamp   race  education         workclass  \
# 0         0 2022-10-01 00:00:00+00:00  White  Bachelors         State-gov
# 1         1 2022-10-01 00:00:00+00:00  White  Bachelors  Self-emp-not-inc
# 2         2 2022-10-01 00:00:00+00:00  White    HS-grad           Private
#
#           occupation  capital-gain  capital-loss income
# 0       Adm-clerical          2174             0  <=50K
# 1    Exec-managerial             0             0  <=50K
# 2  Handlers-cleaners             0             0  <=50K

# %%
# Train v2
training_df = store.get_historical_features(entity_df = entity_df, features = adult_income_fs_train_v2)
training_df.to_df()
# Out:
# WARNING:root:_list_feature_views will make breaking changes. Please use _list_batch_feature_views instead. _list_feature_views will behave like _list_all_feature_views in the future.
#    adult_id           event_timestamp  age   race  education  education-num  \
# 0         0 2022-10-01 00:00:00+00:00   39  White  Bachelors             13
# 1         1 2022-10-01 00:00:00+00:00   50  White  Bachelors             13
# 2         2 2022-10-01 00:00:00+00:00   38  White    HS-grad              9
#
#        marital-status   sex native-country         workclass  \
# 0       Never-married  Male  United-States         State-gov
# 1  Married-civ-spouse  Male  United-States  Self-emp-not-inc
# 2            Divorced  Male  United-States           Private
#
#           occupation  capital-gain  capital-loss income
# 0       Adm-clerical          2174             0  <=50K
# 1    Exec-managerial             0             0  <=50K
# 2  Handlers-cleaners             0             0  <=50K

# %% [markdown]
# ## Capturando historical features para batch processing

# %%
# Entidades de interesse
entity_df = pd.DataFrame({"adult_id": [48839, 48840, 48841], "event_timestamp": [datetime(2024,10,1), datetime(2024,10,1), datetime(2024,10,1)]})
entity_df
# Out:
#    adult_id event_timestamp
# 0     48839      2024-10-01
# 1     48840      2024-10-01
# 2     48841      2024-10-01

# %%
# Inference v2
inf_df = store.get_historical_features(entity_df = entity_df, features = adult_income_fs_inf_v2)
inf_df.to_df()
# Out:
# WARNING:root:_list_feature_views will make breaking changes. Please use _list_batch_feature_views instead. _list_feature_views will behave like _list_all_feature_views in the future.
#    adult_id           event_timestamp  age                race  education  \
# 0     48839 2024-10-01 00:00:00+00:00   38               White  Bachelors
# 1     48840 2024-10-01 00:00:00+00:00   44  Asian-Pac-Islander  Bachelors
# 2     48841 2024-10-01 00:00:00+00:00   35               White  Bachelors
#
#    education-num      marital-status   sex native-country     workclass  \
# 0             13  Married-civ-spouse  Male  United-States       Private
# 1             13            Divorced  Male  United-States       Private
# 2             13  Married-civ-spouse  Male  United-States  Self-emp-inc
#
#         occupation  capital-gain  capital-loss
# 0   Prof-specialty             0             0
# 1     Adm-clerical          5455             0
# 2  Exec-managerial             0             0

# %% [markdown]
# # Feature Retrieval (Online Store)

# %% [markdown]
# ## Explorando o online_store.db

# %%
import sqlite3
# Caminho para o arquivo online_store.db
db_path = os.path.join(feature_repo_path, "data", "online_store.db")

# Conectar ao banco de dados SQLite
conn = sqlite3.connect(db_path)
cursor = conn.cursor()

# Listar todas as tabelas disponíveis no banco de dados
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

print("Tabelas no online_store.db:")
for table in tables:
    print(table[0])
# Out:
# Tabelas no online.db:
# adult_income_project_adult_hist_income_data
# adult_income_project_adult_hist_social_data
# adult_income_project_adult_inf_income_data
# adult_income_project_adult_inf_social_data

# %%
# Identificando dados na tabela adult_income_project_adult_inf_income_data
cursor.execute("SELECT * FROM adult_income_project_adult_inf_income_data;")

rows = cursor.fetchall()

print("\nDados da tabela adult_income_project_adult_inf_income_data:")
for row in rows:
    print(row)
# Out:
# Dados da tabela adult_income_project_adult_inf_income_data:
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x81\xbb\x00\x00', 'workclass', b'\x12\tLocal-gov', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x81\xbb\x00\x00', 'occupation', b'\x12\x0cAdm-clerical', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x81\xbb\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x81\xbb\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xaa\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xaa\xbd\x00\x00', 'occupation', b'\x12\x05Sales', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xaa\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xaa\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xab\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xab\xbd\x00\x00', 'occupation', b'\x12\x05Sales', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xab\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xab\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xac\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xac\xbd\x00\x00', 'occupation', b'\x12\x0eProf-specialty', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xac\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xac\xbd\x00\x00', 'capital-loss', b' \xb6\x0c', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xad\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xad\xbd\x00\x00', 'occupation', b'\x12\x05Sales', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xad\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xad\xbd\x00\x00', 'capital-loss', b' \xb9\x0f', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xae\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xae\xbd\x00\x00', 'occupation', b'\x12\x0fExec-managerial', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xae\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xae\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xaf\xbd\x00\x00', 'workclass', b'\x12\x0bFederal-gov', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xaf\xbd\x00\x00', 'occupation', b'\x12\x0cCraft-repair', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xaf\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xaf\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb0\xbd\x00\x00', 'workclass', b'\x12\x10Self-emp-not-inc', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb0\xbd\x00\x00', 'occupation', b'\x12\x0eProf-specialty', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb0\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb0\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb1\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb1\xbd\x00\x00', 'occupation', b'\x12\x11Machine-op-inspct', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb1\xbd\x00\x00', 'capital-gain', b' \x829', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb1\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb2\xbd\x00\x00', 'workclass', b'', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb2\xbd\x00\x00', 'occupation', b'', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb2\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb2\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb3\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb3\xbd\x00\x00', 'occupation', b'\x12\x11Handlers-cleaners', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb3\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb3\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa9\xbd\x00\x00', 'workclass', b'', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa9\xbd\x00\x00', 'occupation', b'', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa9\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa9\xbd\x00\x00', 'capital-loss', b' \xb6\x0f', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb4\xbd\x00\x00', 'workclass', b'\x12\x10Self-emp-not-inc', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb4\xbd\x00\x00', 'occupation', b'\x12\x0fFarming-fishing', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb4\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb4\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb6\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb6\xbd\x00\x00', 'occupation', b'\x12\rOther-service', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb6\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb6\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb7\xbd\x00\x00', 'workclass', b'', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb7\xbd\x00\x00', 'occupation', b'', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb7\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb7\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb8\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb8\xbd\x00\x00', 'occupation', b'\x12\x05Sales', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb8\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb8\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb9\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb9\xbd\x00\x00', 'occupation', b'\x12\x0cCraft-repair', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb9\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb9\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xba\xbd\x00\x00', 'workclass', b'\x12\tLocal-gov', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xba\xbd\x00\x00', 'occupation', b'\x12\x0eProf-specialty', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xba\xbd\x00\x00', 'capital-gain', b' \x88<', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xba\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xbb\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xbb\xbd\x00\x00', 'occupation', b'\x12\x05Sales', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xbb\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xbb\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xbc\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xbc\xbd\x00\x00', 'occupation', b'\x12\rOther-service', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xbc\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xbc\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xbd\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xbd\xbd\x00\x00', 'occupation', b'\x12\x11Handlers-cleaners', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xbd\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xbd\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xbe\xbd\x00\x00', 'workclass', b'\x12\x10Self-emp-not-inc', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xbe\xbd\x00\x00', 'occupation', b'\x12\x0cCraft-repair', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xbe\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xbe\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xbf\xbd\x00\x00', 'workclass', b'\x12\x10Self-emp-not-inc', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xbf\xbd\x00\x00', 'occupation', b'\x12\x05Sales', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xbf\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xbf\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb5\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb5\xbd\x00\x00', 'occupation', b'\x12\x0cAdm-clerical', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb5\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xb5\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc0\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc0\xbd\x00\x00', 'occupation', b'\x12\x0eProf-specialty', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc0\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc0\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa8\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa8\xbd\x00\x00', 'occupation', b'\x12\x0cAdm-clerical', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa8\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa8\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa6\xbd\x00\x00', 'workclass', b'\x12\x0bFederal-gov', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa6\xbd\x00\x00', 'occupation', b'\x12\x0eProf-specialty', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa6\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa6\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x90\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x90\xbd\x00\x00', 'occupation', b'\x12\x0cCraft-repair', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x90\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x90\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x91\xbd\x00\x00', 'workclass', b'\x12\tState-gov', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x91\xbd\x00\x00', 'occupation', b'\x12\x11Handlers-cleaners', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x91\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x91\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x92\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x92\xbd\x00\x00', 'occupation', b'\x12\x0cAdm-clerical', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x92\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x92\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x93\xbd\x00\x00', 'workclass', b'\x12\x0bFederal-gov', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x93\xbd\x00\x00', 'occupation', b'\x12\x0fProtective-serv', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x93\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x93\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x94\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x94\xbd\x00\x00', 'occupation', b'\x12\x0cTech-support', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x94\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x94\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x95\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x95\xbd\x00\x00', 'occupation', b'\x12\x0cCraft-repair', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x95\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x95\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x96\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x96\xbd\x00\x00', 'occupation', b'\x12\x05Sales', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x96\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x96\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x97\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x97\xbd\x00\x00', 'occupation', b'\x12\x11Handlers-cleaners', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x97\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x97\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x98\xbd\x00\x00', 'workclass', b'\x12\tLocal-gov', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x98\xbd\x00\x00', 'occupation', b'\x12\x0cAdm-clerical', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x98\xbd\x00\x00', 'capital-gain', b' \x94\x17', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x98\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x99\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x99\xbd\x00\x00', 'occupation', b'\x12\x0cAdm-clerical', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x99\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x99\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa7\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa7\xbd\x00\x00', 'occupation', b'\x12\x11Machine-op-inspct', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa7\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa7\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9a\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9a\xbd\x00\x00', 'occupation', b'\x12\rOther-service', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9a\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9a\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9c\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9c\xbd\x00\x00', 'occupation', b'\x12\x0cAdm-clerical', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9c\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9c\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9d\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9d\xbd\x00\x00', 'occupation', b'\x12\x11Machine-op-inspct', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9d\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9d\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9e\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9e\xbd\x00\x00', 'occupation', b'\x12\x0cCraft-repair', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9e\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9e\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9f\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9f\xbd\x00\x00', 'occupation', b'\x12\x10Transport-moving', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9f\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9f\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa0\xbd\x00\x00', 'workclass', b'', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa0\xbd\x00\x00', 'occupation', b'', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa0\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa0\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa1\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa1\xbd\x00\x00', 'occupation', b'\x12\x0eProf-specialty', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa1\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa1\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa2\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa2\xbd\x00\x00', 'occupation', b'\x12\x0fExec-managerial', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa2\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa2\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa3\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa3\xbd\x00\x00', 'occupation', b'\x12\x11Handlers-cleaners', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa3\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa3\xbd\x00\x00', 'capital-loss', b' \xcd\x0b', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa4\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa4\xbd\x00\x00', 'occupation', b'\x12\x0cAdm-clerical', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa4\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa4\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa5\xbd\x00\x00', 'workclass', b'', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa5\xbd\x00\x00', 'occupation', b'', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa5\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa5\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9b\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9b\xbd\x00\x00', 'occupation', b'\x12\x11Handlers-cleaners', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9b\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9b\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc1\xbd\x00\x00', 'workclass', b'\x12\tLocal-gov', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc1\xbd\x00\x00', 'occupation', b'\x12\x0cCraft-repair', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc1\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc1\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc2\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc2\xbd\x00\x00', 'occupation', b'\x12\rOther-service', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc2\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc2\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc3\xbd\x00\x00', 'workclass', b'', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc3\xbd\x00\x00', 'occupation', b'', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc3\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc3\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xdf\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xdf\xbd\x00\x00', 'occupation', b'\x12\x0fFarming-fishing', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xdf\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xdf\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe0\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe0\xbd\x00\x00', 'occupation', b'\x12\x0cAdm-clerical', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe0\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe0\xbd\x00\x00', 'capital-loss', b' \xb6\x0c', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe1\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe1\xbd\x00\x00', 'occupation', b'\x12\x0cTech-support', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe1\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe1\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe2\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe2\xbd\x00\x00', 'occupation', b'\x12\rOther-service', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe2\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe2\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe3\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe3\xbd\x00\x00', 'occupation', b'\x12\x0cTech-support', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe3\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe3\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe4\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe4\xbd\x00\x00', 'occupation', b'\x12\x0cTech-support', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe4\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe4\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe5\xbd\x00\x00', 'workclass', b'\x12\x10Self-emp-not-inc', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe5\xbd\x00\x00', 'occupation', b'\x12\x0eProf-specialty', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe5\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe5\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe6\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe6\xbd\x00\x00', 'occupation', b'\x12\rOther-service', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe6\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe6\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe7\xbd\x00\x00', 'workclass', b'\x12\tLocal-gov', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe7\xbd\x00\x00', 'occupation', b'\x12\x0cAdm-clerical', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe7\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe7\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe8\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe8\xbd\x00\x00', 'occupation', b'\x12\x05Sales', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe8\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe8\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xde\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xde\xbd\x00\x00', 'occupation', b'\x12\x0fPriv-house-serv', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xde\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xde\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe9\xbd\x00\x00', 'workclass', b'\x12\x10Self-emp-not-inc', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe9\xbd\x00\x00', 'occupation', b'\x12\rOther-service', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe9\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xe9\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xeb\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xeb\xbd\x00\x00', 'occupation', b'\x12\x10Transport-moving', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xeb\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xeb\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xec\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xec\xbd\x00\x00', 'occupation', b'\x12\x05Sales', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xec\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xec\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xed\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xed\xbd\x00\x00', 'occupation', b'\x12\x0fExec-managerial', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xed\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xed\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xee\xbd\x00\x00', 'workclass', b'\x12\x10Self-emp-not-inc', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xee\xbd\x00\x00', 'occupation', b'\x12\x05Sales', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xee\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xee\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xef\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xef\xbd\x00\x00', 'occupation', b'\x12\x0fExec-managerial', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xef\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xef\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xf0\xbd\x00\x00', 'workclass', b'\x12\x0cSelf-emp-inc', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xf0\xbd\x00\x00', 'occupation', b'\x12\x11Handlers-cleaners', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xf0\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xf0\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xf1\xbd\x00\x00', 'workclass', b'\x12\x10Self-emp-not-inc', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xf1\xbd\x00\x00', 'occupation', b'\x12\x05Sales', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xf1\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xf1\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xf2\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xf2\xbd\x00\x00', 'occupation', b'\x12\x0cAdm-clerical', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xf2\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xf2\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xf3\xbd\x00\x00', 'workclass', b'\x12\x0cSelf-emp-inc', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xf3\xbd\x00\x00', 'occupation', b'\x12\x0cTech-support', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xf3\xbd\x00\x00', 'capital-gain', b' \x829', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xf3\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xf4\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xf4\xbd\x00\x00', 'occupation', b'\x12\x0eProf-specialty', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xf4\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xf4\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xea\xbd\x00\x00', 'workclass', b'\x12\tLocal-gov', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xea\xbd\x00\x00', 'occupation', b'\x12\x11Machine-op-inspct', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xea\xbd\x00\x00', 'capital-gain', b' \xf4\x0f', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xea\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xdd\xbd\x00\x00', 'workclass', b'\x12\tState-gov', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xdd\xbd\x00\x00', 'occupation', b'\x12\x0fProtective-serv', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xdd\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xdd\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xdc\xbd\x00\x00', 'workclass', b'\x12\tState-gov', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xdc\xbd\x00\x00', 'occupation', b'\x12\x10Transport-moving', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xdc\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xdc\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xdb\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xdb\xbd\x00\x00', 'occupation', b'\x12\rOther-service', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xdb\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xdb\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc4\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc4\xbd\x00\x00', 'occupation', b'\x12\x11Handlers-cleaners', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc4\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc4\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc5\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc5\xbd\x00\x00', 'occupation', b'\x12\x0fExec-managerial', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc5\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc5\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc6\xbd\x00\x00', 'workclass', b'\x12\x10Self-emp-not-inc', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc6\xbd\x00\x00', 'occupation', b'\x12\x0eProf-specialty', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc6\xbd\x00\x00', 'capital-gain', b' \x9f\x8d\x06', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc6\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc7\xbd\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc7\xbd\x00\x00', 'occupation', b'\x12\x05Sales', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc7\xbd\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc7\xbd\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc8\xbd\x00\x00', 'workclass', b'\x12\x0cSelf-emp-inc', None, '2024-10-01 00:00:00', None)
# ...
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa2\xbc\x00\x00', 'occupation', b'\x12\x10Transport-moving', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa2\xbc\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa2\xbc\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa1\xbc\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa1\xbc\x00\x00', 'occupation', b'\x12\x05Sales', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa1\xbc\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa1\xbc\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa0\xbc\x00\x00', 'workclass', b'\x12\tState-gov', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa0\xbc\x00\x00', 'occupation', b'\x12\x0cAdm-clerical', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa0\xbc\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xa0\xbc\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x89\xbc\x00\x00', 'workclass', b'\x12\tLocal-gov', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x89\xbc\x00\x00', 'occupation', b'\x12\x0eProf-specialty', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x89\xbc\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x89\xbc\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x8a\xbc\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x8a\xbc\x00\x00', 'occupation', b'\x12\x0fExec-managerial', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x8a\xbc\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x8a\xbc\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x8b\xbc\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x8b\xbc\x00\x00', 'occupation', b'\x12\x11Machine-op-inspct', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x8b\xbc\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x8b\xbc\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x8c\xbc\x00\x00', 'workclass', b'\x12\tLocal-gov', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x8c\xbc\x00\x00', 'occupation', b'\x12\x0fProtective-serv', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x8c\xbc\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x8c\xbc\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x8d\xbc\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x8d\xbc\x00\x00', 'occupation', b'\x12\x0fExec-managerial', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x8d\xbc\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x8d\xbc\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x8e\xbc\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x8e\xbc\x00\x00', 'occupation', b'\x12\x0cCraft-repair', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x8e\xbc\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x8e\xbc\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x8f\xbc\x00\x00', 'workclass', b'', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x8f\xbc\x00\x00', 'occupation', b'', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x8f\xbc\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x8f\xbc\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x90\xbc\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x90\xbc\x00\x00', 'occupation', b'\x12\rOther-service', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x90\xbc\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x90\xbc\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x91\xbc\x00\x00', 'workclass', b'', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x91\xbc\x00\x00', 'occupation', b'', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x91\xbc\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x91\xbc\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x92\xbc\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x92\xbc\x00\x00', 'occupation', b'\x12\x10Transport-moving', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x92\xbc\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x92\xbc\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x93\xbc\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x93\xbc\x00\x00', 'occupation', b'\x12\x0fExec-managerial', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x93\xbc\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x93\xbc\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x94\xbc\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x94\xbc\x00\x00', 'occupation', b'\x12\x11Machine-op-inspct', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x94\xbc\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x94\xbc\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x95\xbc\x00\x00', 'workclass', b'\x12\x0bFederal-gov', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x95\xbc\x00\x00', 'occupation', b'\x12\x0cAdm-clerical', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x95\xbc\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x95\xbc\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x96\xbc\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x96\xbc\x00\x00', 'occupation', b'\x12\x0fExec-managerial', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x96\xbc\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x96\xbc\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x97\xbc\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x97\xbc\x00\x00', 'occupation', b'\x12\x11Machine-op-inspct', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x97\xbc\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x97\xbc\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x98\xbc\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x98\xbc\x00\x00', 'occupation', b'\x12\x0cTech-support', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x98\xbc\x00\x00', 'capital-gain', b' \x9f\x18', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x98\xbc\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x99\xbc\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x99\xbc\x00\x00', 'occupation', b'\x12\x0fFarming-fishing', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x99\xbc\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x99\xbc\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9a\xbc\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9a\xbc\x00\x00', 'occupation', b'\x12\x0fFarming-fishing', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9a\xbc\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9a\xbc\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9b\xbc\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9b\xbc\x00\x00', 'occupation', b'\x12\x0cCraft-repair', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9b\xbc\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9b\xbc\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9c\xbc\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9c\xbc\x00\x00', 'occupation', b'\x12\x05Sales', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9c\xbc\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9c\xbc\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9d\xbc\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9d\xbc\x00\x00', 'occupation', b'\x12\x0cCraft-repair', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9d\xbc\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9d\xbc\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9e\xbc\x00\x00', 'workclass', b'\x12\x0cSelf-emp-inc', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9e\xbc\x00\x00', 'occupation', b'\x12\x0fExec-managerial', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9e\xbc\x00\x00', 'capital-gain', b' \xb0u', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9e\xbc\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9f\xbc\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9f\xbc\x00\x00', 'occupation', b'\x12\x0cCraft-repair', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9f\xbc\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x9f\xbc\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x87\xbc\x00\x00', 'workclass', b'\x12\x07Private', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x87\xbc\x00\x00', 'occupation', b'\x12\x0fExec-managerial', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x87\xbc\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\x87\xbc\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc9\xbe\x00\x00', 'workclass', b'\x12\x0cSelf-emp-inc', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc9\xbe\x00\x00', 'occupation', b'\x12\x0fExec-managerial', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc9\xbe\x00\x00', 'capital-gain', b' \x00', None, '2024-10-01 00:00:00', None)
# (b'\x02\x00\x00\x00adult_id\x04\x00\x00\x00\x04\x00\x00\x00\xc9\xbe\x00\x00', 'capital-loss', b' \x00', None, '2024-10-01 00:00:00', None)

# %% [markdown]
# ## Online feature retrieval

# %%
# Capturando features (inference_v2)
features = store.get_online_features(
    features=adult_income_fs_inf_v2,
    entity_rows=[
        {
            "adult_id": 48300,
        }
    ],
).to_dict()

features
# Out:
# WARNING:root:_list_feature_views will make breaking changes. Please use _list_batch_feature_views instead. _list_feature_views will behave like _list_all_feature_views in the future.
# WARNING:root:Cannot use sqlite_vec for vector search
# /Users/pedrosilva/Documents/01_Projetos/03_Feast_Test/venv_feast/lib/python3.12/site-packages/feast/infra/online_stores/sqlite.py:220: DeprecationWarning: The default timestamp converter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   rows = cur.fetchall()
# {'adult_id': [48300],
#  'sex': ['Male'],
#  'race': ['White'],
#  'education-num': [13],
#  'marital-status': ['Never-married'],
#  'education': ['Bachelors'],
#  'age': [34],
#  'native-country': ['United-States'],
#  'capital-gain': [0],
#  'occupation': ['Sales'],
#  'capital-loss': [0],
#  'workclass': ['Private']}
